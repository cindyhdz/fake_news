# %%
## Importing our libraries
import pandas as pd
import numpy as np
from config import db_password

# %%
## Create test data df 
fake_test_data = pd.read_csv('./Data/test.csv')

# %%
fake_test_data.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
#  Check null values
fake_test_data.isnull().sum()
# Out:
# id          0
# title     122
# author    503
# text        7
# dtype: int64

# %%
# Droping null values
fake_test_df=fake_test_data.dropna()

# %%
fake_test_df
# Out:
#          id                                              title  \
# 0     20800  Specter of Trump Loosens Tongues, if Not Purse...
# 2     20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3     20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4     20804                    Keiser Report: Meme Wars (E995)
# 6     20806  Pelosi Calls for FBI Investigation to Find Out...
# ...     ...                                                ...
# 5194  25994  Trump on If ’Tapes’ Exist of Comey Conversatio...
# 5195  25995  The Bangladeshi Traffic Jam That Never Ends - ...
# 5196  25996  John Kasich Signs One Abortion Bill in Ohio bu...
# 5197  25997  California Today: What, Exactly, Is in Your Su...
# 5199  25999  Awkward Sex, Onscreen and Off - The New York T...
#
#                        author  \
# 0            David Streitfeld
# 2               Common Dreams
# 3               Daniel Victor
# 4     Truth Broadcast Network
# 6                     Pam Key
# ...

# %%
#dropping non-english characters 
fake_test_df[fake_test_df.title.map(lambda x: x.isascii())]
# Out:
#          id                                              title  \
# 0     20800  Specter of Trump Loosens Tongues, if Not Purse...
# 2     20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3     20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4     20804                    Keiser Report: Meme Wars (E995)
# 10    20810  184 U.S. generals and admirals endorse Trump f...
# ...     ...                                                ...
# 5193  25993  Toyota Recalls 1.4 Million Vehicles as 2nd Maj...
# 5195  25995  The Bangladeshi Traffic Jam That Never Ends - ...
# 5196  25996  John Kasich Signs One Abortion Bill in Ohio bu...
# 5197  25997  California Today: What, Exactly, Is in Your Su...
# 5199  25999  Awkward Sex, Onscreen and Off - The New York T...
#
#                                  author  \
# 0                      David Streitfeld
# 2                         Common Dreams
# 3                         Daniel Victor
# 4               Truth Broadcast Network
# ...

# %%
# Creating cleaned table in sql 

from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_test_df.to_sql(name='fake_test', if_exists='replace',con=engine)
# Out:
# 575

# %%
## Created our database 
fake_train_data = pd.read_csv('./Data/train.csv')

# %%
fake_train_data.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \r\nAn Iranian woman has been sentenced ...      1

# %%
#  Check null values
fake_train_data.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
# Droping null values
fake_news_df=fake_train_data.dropna()

# %%
fake_news_df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
#dropping non-english characters 
fake_news_df[fake_news_df.title.map(lambda x: x.isascii())]
# Out:
#           id                                              title  \
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# 5          5  Jackie Mason: Hollywood Would Love Trump if He...
# ...      ...                                                ...
# 20792  20792  Jakarta Bombing Kills Three Police Officers, L...
# 20793  20793  Idiot Who Destroyed Trump Hollywood Star Gets ...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                    author                                               text  \
# 1         Daniel J. Flynn  Ever get the feeling your life circles the rou...
# ...

# %%
# Creating cleaned table in sql 

from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_news_df.to_sql(name='fake_news', if_exists='replace',con=engine)
# Out:
# 285

# %%
# Extracting after joined both tables and dropped nulls 

from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_news_clean= pd.read_sql('SELECT * FROM joined_df', engine)

fake_news_clean.head()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     718     def do_execute(self, cursor, statement, parameters, context=None):
# --> 719         cursor.execute(statement, parameters)
#     720
#
# UndefinedTable: relation "joined_df" does not exist
# LINE 1: SELECT * FROM joined_df
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Merged data from 'title' & 'author' columns to new column 'merged'

fake_news_clean["merged"] = fake_news_clean["title"]+" "+fake_news_clean["author"]

fake_news_clean.head()

# %%
# Updating all columns 

fake_news_clean.columns = ['ID', 'Title', 'Author', 'Text', 'Label', 'Merged']

fake_news_clean.head()

# %%
# Creating final dataframe after cleaning 

fake_news_final = fake_news_clean

fake_news_final.head()

# %%
# 
from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_news_final.to_sql(name='fake_news_final', if_exists='replace',index= False, con=engine)

# %%
fake_news_final.to_csv('fake_news_final.csv', index=False)

# %%
fact_label = fake_news_final[fake_news_final.Label == 0]
fact_label.head()

# %%
fake_label = fake_news_final[fake_news_final.Label == 1]
fake_label.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18852/3191306625.py in <module>
# ----> 1 fake_label = fake_news_final[fake_news_final.Label == 1]
#       2 fake_label.head()
#
# NameError: name 'fake_news_final' is not defined

# %%
fact_label.to_csv('fact_label.csv', index=False)

# %%
fake_label.to_csv('fake_label.csv', index=False)
