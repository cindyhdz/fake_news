# %%
## Importing our libraries
import pandas as pd
import numpy as np
from config import db_password

# %%
## Create test data
fake_test_data = pd.read_csv('./Data/test.csv')

# %%
fake_test_data.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_test_data.to_sql(name='fake_test', if_exists='replace',con=engine)
# Out:
# 200

# %%
## Created our database 
fake_news_df = pd.read_csv('./Data/train.csv')

# %%
fake_news_df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \r\nAn Iranian woman has been sentenced ...      1

# %%
from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_news_df.to_sql(name='fake_news', if_exists='replace',con=engine)
# Out:
# 800

# %%
#  Check null values
fake_news_df.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
# Droping null values
fake_news_clean=fake_news_df.dropna()

# %%
fake_news_clean
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_news_clean.to_sql(name='fake_news_clean', if_exists='replace',con=engine)
# Out:
# 285

# %%
# ## Merge data for new column of merged columns

fake_news_clean["merged"] = fake_news_clean["title"]+" "+fake_news_clean["author"]

fake_news_clean.head()
# Out:
# C:\Users\vida_\AppData\Local\Temp/ipykernel_13964/3963466955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fake_news_clean["merged"] = fake_news_clean["title"]+" "+fake_news_clean["author"]
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# ...

# %%
fake_news_clean.columns = ['ID', 'Title', 'Author', 'Text', 'Label', 'Merged']

fake_news_clean.head()
# Out:
#    ID                                              Title              Author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 Text  Label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \r\nAn Iranian woman has been sentenced ...      1
#
#                                               Merged
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# ...

# %%
fake_news_final = fake_news_clean

fake_news_final.head()
# Out:
#    ID                                              Title              Author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 Text  Label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \r\nAn Iranian woman has been sentenced ...      1
#
#                                               Merged
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# ...

# %%
from sqlalchemy import create_engine

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fake_news_db"
engine = create_engine(db_string)

fake_news_final.to_sql(name='fake_news_final', if_exists='replace',index= False, con=engine)
# Out:
# 285
